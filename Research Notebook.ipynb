# %%
import yfinance as yf
import pandas as pd

# %%
# get all constituents of HSLMI via tickers Hang Seng Large Mid Cap investable index HSLMI maybe use HSLMIV?
# store in ticker obj
# yfinance dowloads w ticker (symbol), need to get symbol for each comp

# %%
HSIML = pd.read_excel(io = '/Users/lucius/POM/Short Term Momentum/HSIML Constituents list.xlsx',engine = 'openpyxl')
CompSC = HSIML['Stock Code']
len(CompSC.index[CompSC == 'Stock Code'])
# Out:
# 30

# %%
len(CompSC.index[CompSC.apply(type) != int])
# Out:
# 30

# %%
CompSC
# Out:
# 0             883
# 1             857
# 2            1088
# 3             386
# 4            1171
#           ...
# 328          1415
# 329    Stock Code
# 330          1199
# 331          2039
# 332           636
# Name: Stock Code, Length: 333, dtype: object

# %%
yf.Lookup('SHIP').stock
# Out:
#           exchange                                       industryLink  \
# symbol
# SHIP           NCM       https://finance.yahoo.com/sector/industrials
# ZIM            NYQ       https://finance.yahoo.com/sector/industrials
# DSX            NYQ       https://finance.yahoo.com/sector/industrials
# ASC            NYQ       https://finance.yahoo.com/sector/industrials
# CICOY          PNK       https://finance.yahoo.com/sector/industrials
# FSHP           NGM  https://finance.yahoo.com/sector/financial_ser...
# PSHG           NCM       https://finance.yahoo.com/sector/industrials
# 3763.T         JPX        https://finance.yahoo.com/sector/technology
# MPCC.OL        OSL       https://finance.yahoo.com/sector/industrials
# GSL-PB         NYQ       https://finance.yahoo.com/sector/industrials
# TOPS           ASE            https://finance.yahoo.com/sector/energy
# 009540.KS      KSC       https://finance.yahoo.com/sector/industrials
# ...

# %%
yf.download('COSCO SHIP PORT',start='2025-01-01',end='2025-11-10')
# Out:
# /var/folders/9q/5mth65fs50q30lwhn0tw6wnc0000gn/T/ipykernel_63770/462607767.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download('COSCO SHIP PORT',start='2025-01-01',end='2025-11-10')
# [                       0%                       ]HTTP Error 404:
# HTTP Error 404:
# [*********************100%***********************]  3 of 3 completed
#
# 2 Failed downloads:
# ['PORT', 'COSCO']: YFTzMissingError('possibly delisted; no timezone found')
# Price      Adj Close      Close                 High                  Low  \
# Ticker         COSCO PORT COSCO PORT      SHIP COSCO PORT      SHIP COSCO
# Date
# 2025-01-02       NaN  NaN   NaN  NaN  6.845728   NaN  NaN  7.108277   NaN
# 2025-01-03       NaN  NaN   NaN  NaN  6.680419   NaN  NaN  6.884624   NaN
# 2025-01-06       NaN  NaN   NaN  NaN  6.447042   NaN  NaN  6.729040   NaN
# 2025-01-07       NaN  NaN   NaN  NaN  6.660971   NaN  NaN  6.670695   NaN
# ...
